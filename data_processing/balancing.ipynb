# %% [markdown]
# # Data Balancing

# %%
import pandas as pd

from imblearn.over_sampling import SMOTE

# %%
seed = 42

# %%
dataset = pd.read_csv("../datasets/thyroid0387_imputed.data", sep = ";", index_col="Unnamed: 0")

# %%
dataset.dropna()["diagnosis_group"].value_counts()
# Out:
# diagnosis_group
# normal                   6171
# hypothyroid               543
# general_health            416
# replacement_therapy       323
# binding_protein           305
# misc                      239
# hyperthyroid              184
# antithyroid_treatment      30
# Name: count, dtype: int64

# %% [markdown]
# The data is heavely unbalanced, let's fix it.

# %%
x = dataset.drop(columns = ["diagnosis_group", "diagnosis"])
y = dataset["diagnosis_group"]

# %%
smote = SMOTE(random_state = seed)
x_value, y_value = smote.fit_resample(x, y)

# %%
x_value.isnull().sum()
# Out:
# age                          0
# on_thyroxine                 0
# query_on_thyroxine           0
# on_antithyroid_medication    0
# sick                         0
# pregnant                     0
# thyroid_surgery              0
# I131_treatment               0
# query_hypothyroid            0
# query_hyperthyroid           0
# lithium                      0
# goitre                       0
# tumor                        0
# hypopituitary                0
# psych                        0
# sex_M                        0
# TSH_value                    0
# T3_value                     0
# TT4_value                    0
# T4U_value                    0
# FTI_value                    0
# TBG_value                    0
# ref_STMW                     0
# ref_SVHC                     0
# ref_SVHD                     0
# ref_SVI                      0
# ref_WEST                     0
# ref_other                    0
# dtype: int64

# %%
temp = pd.concat([x_value, y_value])

# %%
temp["diagnosis_group"].value_counts()
# Out:
# diagnosis_group
# normal                   6171
# misc                     6171
# hypothyroid              6171
# hyperthyroid             6171
# binding_protein          6171
# replacement_therapy      6171
# general_health           6171
# antithyroid_treatment    6171
# Name: count, dtype: int64

# %%
temp.isnull().sum()
# Out:
# age                          49368
# on_thyroxine                 49368
# query_on_thyroxine           49368
# on_antithyroid_medication    49368
# sick                         49368
# pregnant                     49368
# thyroid_surgery              49368
# I131_treatment               49368
# query_hypothyroid            49368
# query_hyperthyroid           49368
# lithium                      49368
# goitre                       49368
# tumor                        49368
# hypopituitary                49368
# psych                        49368
# sex_M                        49368
# TSH_value                    49368
# T3_value                     49368
# TT4_value                    49368
# T4U_value                    49368
# FTI_value                    49368
# TBG_value                    49368
# ref_STMW                     49368
# ref_SVHC                     49368
# ref_SVHD                     49368
# ref_SVI                      49368
# ref_WEST                     49368
# ref_other                    49368
# diagnosis_group              49368
# dtype: int64

# %%
temp.to_csv("../datasets/thyroid0387_balanced.data", sep=";")
