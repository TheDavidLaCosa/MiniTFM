# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score

import joblib
import optuna

import matplotlib.pyplot as plt
import seaborn as sns

# %%
seed = 42

# %%
dataset = pd.read_csv("./datasets/thyroid0387_imputed.data", sep = ";", index_col="Unnamed: 0")

# %%
numeric_col = dataset.select_dtypes(include = ["int64", "float64"]).columns

scaler = StandardScaler()
dataset[numeric_col] = scaler.fit_transform(dataset[numeric_col])

# %%
dataset["diagnosis_group"].value_counts()
# Out:
# diagnosis_group
# normal                   6446
# hypothyroid               572
# general_health            435
# replacement_therapy       336
# binding_protein           324
# misc                      221
# hyperthyroid              184
# antithyroid_treatment      33
# Name: count, dtype: int64

# %%
dataset.isnull().sum().sort_values(ascending=False)
# Out:
# age                          0
# on_thyroxine                 0
# ref_WEST                     0
# ref_SVI                      0
# ref_SVHD                     0
# ref_SVHC                     0
# ref_STMW                     0
# TBG_value                    0
# FTI_value                    0
# T4U_value                    0
# TT4_value                    0
# T3_value                     0
# TSH_value                    0
# sex_M                        0
# diagnosis_group              0
# diagnosis                    0
# psych                        0
# hypopituitary                0
# tumor                        0
# goitre                       0
# lithium                      0
# query_hyperthyroid           0
# query_hypothyroid            0
# I131_treatment               0
# thyroid_surgery              0
# pregnant                     0
# sick                         0
# on_antithyroid_medication    0
# query_on_thyroxine           0
# ref_other                    0
# dtype: int64

# %%
dataset.dropna()["diagnosis_group"].value_counts()
# Out:
# diagnosis_group
# normal                   6446
# hypothyroid               572
# general_health            435
# replacement_therapy       336
# binding_protein           324
# misc                      221
# hyperthyroid              184
# antithyroid_treatment      33
# Name: count, dtype: int64

# %%
dataset.head()
# Out:
#         age  on_thyroxine  query_on_thyroxine  on_antithyroid_medication  \
# 0 -1.236522         False               False                      False
# 1 -1.236522         False               False                      False
# 2 -0.600043         False               False                      False
# 3 -0.865243         False               False                      False
# 4 -1.077402         False               False                      False
#
#     sick  pregnant  thyroid_surgery  I131_treatment  query_hypothyroid  \
# 0  False     False            False           False               True
# 1  False     False            False           False              False
# 2  False     False            False           False              False
# 3  False     False            False           False              False
# 4  False     False            False           False              False
#
#    query_hyperthyroid  ...  TT4_value  T4U_value  FTI_value  TBG_value  \
# 0               False  ...  -0.071379  -0.049085  -0.055753   0.731246
# 1               False  ...   0.510487  -0.003203   0.581059  -0.613711
# 2                True  ...  -0.519746  -1.097706   0.287541  -1.977649
# 3               False  ...  -0.037285   0.234272  -0.153910  -0.070715
# 4               False  ...  -0.459299  -0.862097   0.214125   1.200575
#
#    ref_STMW ref_SVHC ref_SVHD  ref_SVI  ref_WEST  ref_other
# 0     False    False    False    False     False       True
# 1     False    False    False    False     False       True
# 2     False    False    False    False     False       True
# 3     False    False    False    False     False       True
# 4     False    False    False    False     False       True
#
# [5 rows x 30 columns]

# %%
dataset["diagnosis_group"].value_counts()
# Out:
# diagnosis_group
# normal                   6446
# hypothyroid               572
# general_health            435
# replacement_therapy       336
# binding_protein           324
# misc                      221
# hyperthyroid              184
# antithyroid_treatment      33
# Name: count, dtype: int64

# %%
label = LabelEncoder()
dataset["diagnosis_group"] = label.fit_transform(dataset["diagnosis_group"])

print(f"{dict(enumerate(label.classes_))}")
# Out:
# {0: 'antithyroid_treatment', 1: 'binding_protein', 2: 'general_health', 3: 'hyperthyroid', 4: 'hypothyroid', 5: 'misc', 6: 'normal', 7: 'replacement_therapy'}

# %%
x = dataset.drop(columns=["diagnosis_group", "diagnosis"])
y = dataset["diagnosis_group"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = seed)

# %%
print(f"X train: {x_train.shape}\nX test: {x_test.shape}\nY train: {y_train.shape}\nY test: {y_test.shape}")
# Out:
# X train: (5985, 28)
# X test: (2566, 28)
# Y train: (5985,)
# Y test: (2566,)

# %% [markdown]
# ## Model

# %%
knn = KNeighborsClassifier()
knn.fit(x_train, y_train)

y_pred = knn.predict(x_test)
# Out:
# C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# found 0 physical cores < 1
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\Usuario\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\joblib\externals\loky\backend\context.py", line 282, in _count_physical_cores
#     raise ValueError(f"found {cpu_count_physical} physical cores < 1")

# %% [markdown]
# ## Model evaluation

# %%
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"F1 score: {f1_score(y_test, y_pred, average = 'weighted')}")

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
            
plt.xlabel('Predicción')
plt.ylabel('Valor real')
plt.title('Matrix de confusión - Random Forest')
plt.show()
# Out:
# Accuracy: 0.9224473889321901
# F1 score: 0.9193187087231977

# %% [markdown]
# ## Saving model

# %%
joblib.dump(knn, "./models_saved/knn.json")
# Out:
# ['./models_saved/knn.json']

# %% [markdown]
# ## Bayesian optimization
#
# Function that will be used during the optimization

# %%
def objective(trial):
    params = {
        "p": trial.suggest_int("p", 1, 2),
        "weights": trial.suggest_categorical("weights", ["uniform", "distance"]),
        "n_neighbors": trial.suggest_int("n_neighbors", 3, 30),
        "algorithm": trial.suggest_categorical("algorithm", ["auto", "kd_tree", "brute", "ball_tree"]),
        
        "n_jobs": -1
    }

    model = KNeighborsClassifier(**params)
    model.fit(x_train, y_train)

    y_pred = model.predict(x_test)

    return f1_score(y_test, y_pred, average = "weighted")

# %% [markdown]
# Optimization process

# %%
optimization = optuna.create_study(direction = "maximize")
optimization.optimize(objective, n_trials = 100)
# Out:
# [I 2025-04-17 19:31:18,660] A new study created in memory with name: no-name-02606e40-ce13-4ad9-a9bc-966b70b1de80
# [I 2025-04-17 19:31:20,171] Trial 0 finished with value: 0.9346607924820451 and parameters: {'p': 1, 'weights': 'uniform', 'n_neighbors': 3, 'algorithm': 'auto'}. Best is trial 0 with value: 0.9346607924820451.
# [I 2025-04-17 19:31:22,360] Trial 1 finished with value: 0.8858075095704425 and parameters: {'p': 2, 'weights': 'uniform', 'n_neighbors': 22, 'algorithm': 'ball_tree'}. Best is trial 0 with value: 0.9346607924820451.
# [I 2025-04-17 19:31:23,109] Trial 2 finished with value: 0.8913200810934427 and parameters: {'p': 2, 'weights': 'uniform', 'n_neighbors': 20, 'algorithm': 'auto'}. Best is trial 0 with value: 0.9346607924820451.
# [I 2025-04-17 19:31:23,480] Trial 3 finished with value: 0.8806828955647341 and parameters: {'p': 2, 'weights': 'uniform', 'n_neighbors': 27, 'algorithm': 'brute'}. Best is trial 0 with value: 0.9346607924820451.
# [I 2025-04-17 19:31:23,764] Trial 4 finished with value: 0.8995300599979401 and parameters: {'p': 2, 'weights': 'distance', 'n_neighbors': 18, 'algorithm': 'brute'}. Best is trial 0 with value: 0.9346607924820451.
# [I 2025-04-17 19:31:25,676] Trial 5 finished with value: 0.9238288987230893 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 11, 'algorithm': 'kd_tree'}. Best is trial 0 with value: 0.9346607924820451.
# [I 2025-04-17 19:31:28,349] Trial 6 finished with value: 0.9275455975680814 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 7, 'algorithm': 'ball_tree'}. Best is trial 0 with value: 0.9346607924820451.
# [I 2025-04-17 19:31:29,844] Trial 7 finished with value: 0.8997563432248266 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 24, 'algorithm': 'brute'}. Best is trial 0 with value: 0.9346607924820451.
# [I 2025-04-17 19:31:32,584] Trial 8 finished with value: 0.8785798787455926 and parameters: {'p': 2, 'weights': 'uniform', 'n_neighbors': 30, 'algorithm': 'brute'}. Best is trial 0 with value: 0.9346607924820451.
# [I 2025-04-17 19:31:34,925] Trial 9 finished with value: 0.9048640994001927 and parameters: {'p': 2, 'weights': 'distance', 'n_neighbors': 12, 'algorithm': 'brute'}. Best is trial 0 with value: 0.9346607924820451.
# [I 2025-04-17 19:31:37,002] Trial 10 finished with value: 0.9347976372016407 and parameters: {'p': 1, 'weights': 'uniform', 'n_neighbors':
finished with value: 0.9356872595522148 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 6, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:32:49,393] Trial 54 finished with value: 0.9275455975680814 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 7, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:32:50,791] Trial 55 finished with value: 0.9356872595522148 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 6, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:32:52,112] Trial 56 finished with value: 0.9238288987230893 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 11, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:32:53,370] Trial 57 finished with value: 0.9356872595522148 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 6, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:32:54,804] Trial 58 finished with value: 0.9189020615737026 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 13, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:32:56,039] Trial 59 finished with value: 0.9257348707289385 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 10, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:32:57,332] Trial 60 finished with value: 0.9275455975680814 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 7, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:32:58,470] Trial 61 finished with value: 0.9356872595522148 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 6, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:32:58,845] Trial 62 finished with value: 0.9266085152068055 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 9, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:32:59,271] Trial 63 finished with value: 0.9356872595522148 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 6, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:32:59,557] Trial 64 finished with value: 0.9356872595522148 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 6, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:33:00,111] Trial 65 finished with value: 0.9356872595522148 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 6, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:33:01,411] Trial 66 finished with value: 0.9286435748154923 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 8, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:33:02,691] Trial 67 finished with value: 0.9286435748154923 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 8, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:33:04,156] Trial 68 finished with value: 0.9257348707289385 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 10, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:33:05,370] Trial 69 finished with value: 0.9356872595522148 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 6, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:33:06,781] Trial 70 finished with value: 0.9275455975680814 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 7, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:33:07,973] Trial 71 finished with value: 0.9356872595522148 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 6, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:33:08,254] Trial 72 finished with value: 0.9343434166985898 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 5, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:33:08,747] Trial 73 finished with value: 0.9343434166985898 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 5, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:33:09,114] Trial 74 finished with value: 0.9356872595522148 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 6, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:33:09,436] Trial 75 finished with value: 0.9266085152068055 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 9, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:33:10,740] Trial 76 finished with value: 0.9275455975680814 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 7, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:33:12,164] Trial 77 finished with value: 0.9286435748154923 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 8, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:33:13,705] Trial 78 finished with value: 0.9343434166985898 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 5, 'algorithm': 'brute'}. Best is trial 50 with value: 0.9356872595522148.
# [I 2025-04-17 19:33:15,488] Trial 79 finished with value: 0.9365455911344092 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 3, 'algorithm': 'brute'}. Best is trial 79 with value: 0.9365455911344092.
# [I 2025-04-17 19:33:16,980] Trial 80 finished with value: 0.9380493694419438 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 4, 'algorithm': 'brute'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:18,596] Trial 81 finished with value: 0.9365455911344092 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 3, 'algorithm': 'brute'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:19,656] Trial 82 finished with value: 0.9365455911344092 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 3, 'algorithm': 'brute'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:20,070] Trial 83 finished with value: 0.9365455911344092 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 3, 'algorithm': 'brute'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:20,570] Trial 84 finished with value: 0.9365455911344092 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 3, 'algorithm': 'brute'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:21,044] Trial 85 finished with value: 0.9365455911344092 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 3, 'algorithm': 'brute'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:22,353] Trial 86 finished with value: 0.9365455911344092 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 3, 'algorithm': 'ball_tree'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:25,193] Trial 87 finished with value: 0.9365455911344092 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 3, 'algorithm': 'ball_tree'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:28,371] Trial 88 finished with value: 0.9365455911344092 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 3, 'algorithm': 'ball_tree'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:31,333] Trial 89 finished with value: 0.9365455911344092 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 3, 'algorithm': 'ball_tree'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:34,344] Trial 90 finished with value: 0.9380493694419438 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 4, 'algorithm': 'ball_tree'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:37,404] Trial 91 finished with value: 0.9380493694419438 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 4, 'algorithm': 'ball_tree'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:40,643] Trial 92 finished with value: 0.9380493694419438 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 4, 'algorithm': 'ball_tree'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:43,812] Trial 93 finished with value: 0.9380493694419438 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 4, 'algorithm': 'ball_tree'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:46,493] Trial 94 finished with value: 0.9380493694419438 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 4, 'algorithm': 'ball_tree'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:48,885] Trial 95 finished with value: 0.9380493694419438 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 4, 'algorithm': 'ball_tree'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:51,901] Trial 96 finished with value: 0.9380493694419438 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 4, 'algorithm': 'ball_tree'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:54,857] Trial 97 finished with value: 0.9380493694419438 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 4, 'algorithm': 'ball_tree'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:33:58,707] Trial 98 finished with value: 0.9277876387489021 and parameters: {'p': 2, 'weights': 'distance', 'n_neighbors': 4, 'algorithm': 'ball_tree'}. Best is trial 80 with value: 0.9380493694419438.
# [I 2025-04-17 19:34:03,367] Trial 99 finished with value: 0.9380493694419438 and parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 4, 'algorithm': 'ball_tree'}. Best is trial 80 with value: 0.9380493694419438.

# %%
print(f"Best parameters: {optimization.best_params}")
# Out:
# Best parameters: {'p': 1, 'weights': 'distance', 'n_neighbors': 4, 'algorithm': 'brute'}

# %%
knn = KNeighborsClassifier(**optimization.best_params)
knn.fit(x_train, y_train)

y_pred = knn.predict(x_test)

# %%
print(f"Accuracy: {accuracy_score(y_test, y_pred)}")
print(f"F1 score: {f1_score(y_test, y_pred, average = 'weighted')}")
# Out:
# Accuracy: 0.9395946999220577
# F1 score: 0.9380493694419438

# %%
joblib.dump(knn, "./models_saved/knn_opt.json")
# Out:
# ['./models_saved/knn_opt.json']
